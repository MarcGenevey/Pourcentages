# %% [markdown]
# ![banniere_pourcentages.jpg](attachment:banniere_pourcentages.jpg)

# %% [markdown]
# <span style="color: #9317B4"> Chaque cellule python ( "Entrée[ ]" dans la marge) doit être validée par la combinaison de touches Shift+Entrée avant de passer à la suivante </span><span style="color: #B317B4"><strong>SHIFT+Entrée</strong></span>.

# %% [markdown]
# # Lien entre évolution et pourcentage

# %% [raw]
# La fonction ci-après permet de calculer la variation relative t pour une quantité évoluant d'une valeur V0 à une valeur V1. A la seconde ligne, complétez la valeur manquante entre parenthèses par la formule de calcul adéquate.

# %%
def tauxevol(v0,v1):
    return ()

# %% [raw]
# Choisissez deux valeurs V0 et V1 simples, et vérifiez ci après que votre fonction retourne bien la valeur attendue

# %%
tauxevol(,)

# %% [raw]
# La fonction suivante permet de calculer le coefficient multiplicateur associé à une évolution de t%

# %%
def cm(t):
    return(1+t/100)

# %% [markdown]
# La fonction suivante permet de calculer la valeur finale V1 pour une quantité évoluant de la valeur V0 à la valeur V1 avec un taux d évolution t. complétez le code.

# %%
def finale(v0,t):
    c=cm(t)
    v_1 =     #complétez cette ligne avec une formule de calcul utilisant les variables c et v_0
    return(v_1)

# %% [raw]
# Testez la fonction finale avec des valeurs de votre choix vous permettant de contrôler le résultat obtenu.

# %%
finale(,)

# %% [raw]
# La fonction suivante permet de calculer la valeur initiale V0 pour une quantité évoluant de la valeur V0 à la valeur V1 avec un taux d évolution t. complétez le code.

# %%
def initiale(v1,t):
    c =cm(t)
    v0=     #complétez cette ligne avec une formule de calcul utilisant les variables c et v1
    return(v0)

# %% [raw]
# Testez la fonction initiale avec des valeurs de votre choix vous permettant de contrôler le résultat obtenu.

# %%
initiale(,)

# %% [markdown]
# # évolutions successives, évolution réciproque

# %% [raw]
# Une évolution de taux t1 fait passer de la valeur V0 non nulle à la valeur V1, et une autre évolution de taux t2 fait passer de la valeur V1 à la valeur V2. la fonction ci-dessous permet de calculer le taux d'évolution global associé

# %%
def tauxglobal(t1,t2):
    c1=tauxevol(t1) 
    c2=           #compléter cette ligne
    c=             #compléter cette ligne
    t=             #compléter cette ligne
    return(t)

# %% [raw]
# Testez la fonction tauxglobal avec des valeurs de votre choix vous permettant de contrôler le résultat obtenu.

# %%
tauxglobal(,)

# %% [raw]
# Une évolution de taux t fait passer de la valeur V0 non nulle à la valeur V1. L'évolution réciproque de taux tr fait passer de la valeur V1 à la valeur V0. Ecrire ci-dessous une fonction tauxrecip qui prend en entrée t1 et qui renvoie tr

# %% [raw]
# Testez la fonction tauxrecip avec des valeurs de votre choix vous permettant de contrôler le résultat obtenu.

# %% [markdown]
# <i>© Copyright Marc GENEVEY, LGT Faustin Fléret 2021-2022 </i><br>
# <i>Les activités partagées sur <a href="https://capytale2.ac-paris.fr/web/accueil"><strong>Capytale</strong></a> sont sous licence <a href="https://creativecommons.org/licenses/by-sa/3.0/fr/">Creative Commons</a>.</i> ![cc_by_nc.png](attachment:cc_by_nc.png)
